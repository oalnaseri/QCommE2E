# %% [markdown]
# # 02 - QAE for FSO Compensation
#
# Train a spatial-mode QAE to mitigate FSO turbulence effects.

# %%
from quantum_comm_sim.autoencoders.spatial_mode_qae import SpatialModeQAE
import numpy as np
